# %% [markdown]
# # Auto-Encoder Example
#
# Build a 2 layers auto-encoder with TensorFlow v2 to compress images to a lower latent space and then reconstruct them.
#
# - Author: Aymeric Damien
# - Project: https://github.com/aymericdamien/TensorFlow-Examples/

# %% [markdown]
# ## Auto-Encoder Overview
#
# <img src="http://kvfrans.com/content/images/2016/08/autoenc.jpg" alt="ae" style="width: 800px;"/>
#
# References:
# - [Gradient-based learning applied to document recognition](http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf). Y. LeCun, L. Bottou, Y. Bengio, and P. Haffner. Proceedings of the IEEE, 86(11):2278-2324, November 1998.
#
# ## MNIST Dataset Overview
#
# This example is using MNIST handwritten digits. The dataset contains 60,000 examples for training and 10,000 examples for testing. The digits have been size-normalized and centered in a fixed-size image (28x28 pixels) with values from 0 to 255.
#
# In this example, each image will be converted to float32, normalized to [0, 1] and flattened to a 1-D array of 784 features (28*28).
#
# ![MNIST Dataset](http://neuralnetworksanddeeplearning.com/images/mnist_100_digits.png)
#
# More info: http://yann.lecun.com/exdb/mnist/

# %%
from __future__ import absolute_import, division, print_function

import tensorflow as tf
import numpy as np
# Out:
# 2025-04-25 22:29:18.727957: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-25 22:29:18.745373: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-25 22:29:18.750563: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-25 22:29:18.764505: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-25 22:29:19.482127: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# MNIST Dataset parameters.
num_features = 784 # data features (img shape: 28*28).

# Training parameters.
learning_rate = 0.01
training_steps = 20000
batch_size = 256
display_step = 1000

# Network Parameters
num_hidden_1 = 128 # 1st layer num features.
num_hidden_2 = 64 # 2nd layer num features (the latent dim).

# %%
# Prepare MNIST data.
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Convert to float32.
x_train, x_test = x_train.astype(np.float32), x_test.astype(np.float32)
# Flatten images to 1-D vector of 784 features (28*28).
x_train, x_test = x_train.reshape([-1, num_features]), x_test.reshape([-1, num_features])
# Normalize images value from [0, 255] to [0, 1].
x_train, x_test = x_train / 255., x_test / 255.

# %%
# Use tf.data API to shuffle and batch data.
train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.repeat().shuffle(10000).batch(batch_size).prefetch(1)

test_data = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_data = test_data.repeat().batch(batch_size).prefetch(1)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745600364.982882  219196 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-25 22:29:25.030957: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2343] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Store layers weight & bias

# A random value generator to initialize weights.
random_normal = tf.initializers.RandomNormal()

weights = {
    'encoder_h1': tf.Variable(random_normal([num_features, num_hidden_1])),
    'encoder_h2': tf.Variable(random_normal([num_hidden_1, num_hidden_2])),
    'decoder_h1': tf.Variable(random_normal([num_hidden_2, num_hidden_1])),
    'decoder_h2': tf.Variable(random_normal([num_hidden_1, num_features])),
}
biases = {
    'encoder_b1': tf.Variable(random_normal([num_hidden_1])),
    'encoder_b2': tf.Variable(random_normal([num_hidden_2])),
    'decoder_b1': tf.Variable(random_normal([num_hidden_1])),
    'decoder_b2': tf.Variable(random_normal([num_features])),
}

# %%
# Building the encoder.
def encoder(x):
    # Encoder Hidden layer with sigmoid activation.
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, weights['encoder_h1']),
                                   biases['encoder_b1']))
    # Encoder Hidden layer with sigmoid activation.
    layer_2 = tf.nn.sigmoid(tf.add(tf.matmul(layer_1, weights['encoder_h2']),
                                   biases['encoder_b2']))
    return layer_2


# Building the decoder.
def decoder(x):
    # Decoder Hidden layer with sigmoid activation.
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, weights['decoder_h1']),
                                   biases['decoder_b1']))
    # Decoder Hidden layer with sigmoid activation.
    layer_2 = tf.nn.sigmoid(tf.add(tf.matmul(layer_1, weights['decoder_h2']),
                                   biases['decoder_b2']))
    return layer_2

# %%
# Mean square loss between original images and reconstructed ones.
def mean_square(reconstructed, original):
    return tf.reduce_mean(tf.pow(original - reconstructed, 2))

# Adam optimizer.
optimizer = tf.optimizers.Adam(learning_rate=learning_rate)

# %%
# Optimization process. 
def run_optimization(x):
    # Wrap computation inside a GradientTape for automatic differentiation.
    with tf.GradientTape() as g:
        reconstructed_image = decoder(encoder(x))
        loss = mean_square(reconstructed_image, x)

    # Variables to update, i.e. trainable variables.
    trainable_variables = list(weights.values()) + list(biases.values())
    
    # Compute gradients.
    gradients = g.gradient(loss, trainable_variables)
    
    # Update W and b following gradients.
    optimizer.apply_gradients(zip(gradients, trainable_variables))
    
    return loss

# %%
# Run training for the given number of steps.
for step, (batch_x, _) in enumerate(train_data.take(training_steps + 1)):
    
    # Run the optimization.
    loss = run_optimization(batch_x)
    
    if step % display_step == 0:
        print("step: %i, loss: %f" % (step, loss))
# Out:
# step: 0, loss: 0.236001
# step: 1000, loss: 0.017066
# step: 2000, loss: 0.010603
# step: 3000, loss: 0.008287
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       1 # Run training for the given number of steps.
#       2 for step, (batch_x, _) in enumerate(train_data.take(training_steps + 1)):
#       3
#       4     # Run the optimization.
# ----> 5     loss = run_optimization(batch_x)
#       7     if step % display_step == 0:
#       8         print("step: %i, loss: %f" % (step, loss))
#
# Cell In[10], line 15, in run_optimization(x)
#      12 gradients = g.gradient(loss, trainable_variables)
#      14 # Update W and b following gradients.
# ---> 15 optimizer.apply_gradients(zip(gradients, trainable_variables))
#      17 return loss
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/optimizers/base_optimizer.py:291, in BaseOptimizer.apply_gradients(self, grads_and_vars)
#     289 def apply_gradients(self, grads_and_vars):
#     290     grads, trainable_variables = zip(*grads_and_vars)
# --> 291     self.apply(grads, trainable_variables)
#     292     # Return iterations for compat with tf.keras.
#     293     return self._iterations
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/optimizers/base_optimizer.py:356, in BaseOptimizer.apply(self, grads, trainable_variables)
#     353     grads = [g if g is None else g / scale for g in grads]
#     355 # Apply gradient updates.
# --> 356 self._backend_apply_gradients(grads, trainable_variables)
#     357 # Apply variable constraints after applying gradients.
#     358 for variable in trainable_variables:
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/optimizers/base_optimizer.py:419, in BaseOptimizer._backend_apply_gradients(self, grads, trainable_variables)
#     416     self._apply_weight_decay(trainable_variables)
#     418     # Run udpate step.
# --> 419     self._backend_update_step(
#     420         grads, trainable_variables, self.learning_rate
#     421     )
#     423 if self.use_ema:
#     424     self._update_model_variables_moving_average(
#     425         self._trainable_variables
#     426     )
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/backend/tensorflow/optimizer.py:121, in TFOptimizer._backend_update_step(self, grads, trainable_variables, learning_rate)
#     119 grads_and_vars = list(zip(grads, trainable_variables))
#     120 grads_and_vars = self._all_reduce_sum_gradients(grads_and_vars)
# --> 121 tf.__internal__.distribute.interim.maybe_merge_call(
#     122     self._distributed_tf_update_step,
#     123     self._distribution_strategy,
#     124     grads_and_vars,
#     125     learning_rate,
#     126 )
#
# File /store/venv/da5401/lib/python3.10/site-packages/tensorflow/python/distribute/merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/backend/tensorflow/optimizer.py:135, in TFOptimizer._distributed_tf_update_step(self, distribution, grads_and_vars, learning_rate)
#     132     return self.update_step(grad, var, learning_rate)
#     134 for grad, var in grads_and_vars:
# --> 135     distribution.extended.update(
#     136         var,
#     137         apply_grad_to_update_var,
#     138         args=(grad, learning_rate),
#     139         group=False,
#     140     )
#
# File /store/venv/da5401/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:3005, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3002   fn = autograph.tf_convert(
#    3003       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3004   with self._container_strategy().scope():
# -> 3005     return self._update(var, fn, args, kwargs, group)
#    3006 else:
#    3007   return self._replica_ctx_update(
#    3008       var, fn, args=args, kwargs=kwargs, group=group)
#
# File /store/venv/da5401/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:4075, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4072 def _update(self, var, fn, args, kwargs, group):
#    4073   # The implementations of _update() and _update_non_slot() are identical
#    4074   # except _update() passes `var` as the first argument to `fn()`.
# -> 4075   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File /store/venv/da5401/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:4081, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4077 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4078   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4079   # once that value is used for something.
#    4080   with UpdateContext(colocate_with):
# -> 4081     result = fn(*args, **kwargs)
#    4082     if should_group:
#    4083       return result
#
# File /store/venv/da5401/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:596, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     594 def wrapper(*args, **kwargs):
#     595   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596     return func(*args, **kwargs)
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/backend/tensorflow/optimizer.py:132, in TFOptimizer._distributed_tf_update_step.<locals>.apply_grad_to_update_var(var, grad, learning_rate)
#     131 def apply_grad_to_update_var(var, grad, learning_rate):
# --> 132     return self.update_step(grad, var, learning_rate)
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/optimizers/adam.py:133, in Adam.update_step(self, gradient, variable, learning_rate)
#     128 v = self._velocities[self._get_variable_index(variable)]
#     130 alpha = lr * ops.sqrt(1 - beta_2_power) / (1 - beta_1_power)
#     132 self.assign_add(
# --> 133     m, ops.multiply(ops.subtract(gradient, m), 1 - self.beta_1)
#     134 )
#     135 self.assign_add(
#     136     v,
#     137     ops.multiply(
#     138         ops.subtract(ops.square(gradient), v), 1 - self.beta_2
#     139     ),
#     140 )
#     141 if self.amsgrad:
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/ops/numpy.py:5512, in multiply(x1, x2)
#    5501 @keras_export(["keras.ops.multiply", "keras.ops.numpy.multiply"])
#    5502 def multiply(x1, x2):
#    5503     """Multiply arguments element-wise.
#    5504
#    5505     Args:
#    (...)
#    5510         Output tensor, element-wise product of `x1` and `x2`.
#    5511     """
# -> 5512     if any_symbolic_tensors((x1, x2)):
#    5513         return Multiply().symbolic_call(x1, x2)
#    5514     return backend.numpy.multiply(x1, x2)
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/backend/common/keras_tensor.py:349, in any_symbolic_tensors(args, kwargs)
#     347 args = args or ()
#     348 kwargs = kwargs or {}
# --> 349 for x in tree.flatten((args, kwargs)):
#     350     if isinstance(x, KerasTensor):
#     351         return True
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/tree/tree_api.py:121, in flatten(structure)
#      91 @keras_export("keras.tree.flatten")
#      92 def flatten(structure):
#      93     """Flattens a possibly nested structure into a list.
#      94
#      95     In the case of dict instances, the sequence consists of the values,
#    (...)
#     119         A list, the flattened version of the input `structure`.
#     120     """
# --> 121     return tree_impl.flatten(structure)
#
# File /store/venv/da5401/lib/python3.10/site-packages/keras/src/tree/optree_impl.py:66, in flatten(structure)
#      62 def flatten(structure):
#      63     # optree.tree_flatten returns a pair (leaves, treespec) where the first
#      64     # element is a list of leaf values and the second element is a treespec
#      65     # representing the structure of the pytree.
# ---> 66     leaves, _ = optree.tree_flatten(
#      67         structure, none_is_leaf=True, namespace="keras"
#      68     )
#      69     return leaves
#
# File /store/venv/da5401/lib/python3.10/site-packages/optree/ops.py:196, in tree_flatten(tree, is_leaf, none_is_leaf, namespace)
#     130 def tree_flatten(
#     131     tree: PyTree[T],
#     132     /,
#    (...)
#     136     namespace: str = '',
#     137 ) -> tuple[list[T], PyTreeSpec]:
#     138     """Flatten a pytree.
#     139
#     140     See also :func:`tree_flatten_with_path` and :func:`tree_unflatten`.
#    (...)
#     194         second element is a treespec representing the structure of the pytree.
#     195     """
# --> 196     return _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#
# KeyboardInterrupt:

# %%
# Testing and Visualization.
import matplotlib.pyplot as plt

# %%
# Encode and decode images from test set and visualize their reconstruction.
n = 4
canvas_orig = np.empty((28 * n, 28 * n))
canvas_recon = np.empty((28 * n, 28 * n))
for i, (batch_x, _) in enumerate(test_data.take(n)):
    # Encode and decode the digit image.
    reconstructed_images = decoder(encoder(batch_x))
    # Display original images.
    for j in range(n):
        # Draw the generated digits.
        img = batch_x[j].numpy().reshape([28, 28])
        canvas_orig[i * 28:(i + 1) * 28, j * 28:(j + 1) * 28] = img
    # Display reconstructed images.
    for j in range(n):
        # Draw the generated digits.
        reconstr_img = reconstructed_images[j].numpy().reshape([28, 28])
        canvas_recon[i * 28:(i + 1) * 28, j * 28:(j + 1) * 28] = reconstr_img

print("Original Images")     
plt.figure(figsize=(n, n))
plt.imshow(canvas_orig, origin="upper", cmap="gray")
plt.show()

print("Reconstructed Images")
plt.figure(figsize=(n, n))
plt.imshow(canvas_recon, origin="upper", cmap="gray")
plt.show()
# Out:
# Original Images
# 2025-04-25 22:35:15.318486: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Reconstructed Images
